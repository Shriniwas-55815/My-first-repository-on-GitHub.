# %% [markdown]
# Libraries

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image as img
import numpy as np

text = '''My name is Shriniwas Uttarkar, and I am a PYTHON Developer with over 4.2 years of professional experience. My expertise lies in PYTHON and PL/PYTHON development, with a proven track record of crafting efficient PYTHON queries, creating and managing procedures, functions, and triggers, and optimizing database performance.
I have experience working with Oracle, MSPYTHON Server, and Power BI to deliver data-driven insights and visualizations. My skill set includes performance tuning, database query analysis, and developing DAX reports by extracting data from diverse sources such as CSV and XML files. I am proficient in tools like Power BI, Advanced Excel, and RDBMS systems, making me adaptable across multiple data management environments.
In addition to my technical skills, I bring strong problem-solving abilities, a knack for innovation, and a collaborative team-player attitude. I am enthusiastic about tackling challenging assignments and am currently looking for opportunities with reputable organizations, preferably in Bengaluru.
'''

Frame= np.array(img.open(r'C:\Users\Shriniwas\Desktop\wish.jpg'))

w = WordCloud(width=800, height=800, mask=Frame, background_color='white').generate(text)


plt.imshow(w, interpolation='bilinear')
plt.axis(False)
plt.tight_layout()
plt.show()
